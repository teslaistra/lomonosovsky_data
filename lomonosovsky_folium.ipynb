# %%
import pandas as pd 
import folium

# %%
df_houses = pd.read_excel("lomonosovsky_removed.xlsx")
df_houses
# Out:
#      Unnamed: 0                                                  ссылка  \
# 0    0           http://www.reformagkh.ru/myhouse/profile/view/8146433/
# 1    1           http://www.reformagkh.ru/myhouse/profile/view/7706328/
# 2    2           http://www.reformagkh.ru/myhouse/profile/view/7693679/
# 3    3           http://www.reformagkh.ru/myhouse/profile/view/7693681/
# 4    4           http://www.reformagkh.ru/myhouse/profile/view/7693683/
# 5    5           http://www.reformagkh.ru/myhouse/profile/view/7693684/
# 6    6           http://www.reformagkh.ru/myhouse/profile/view/7693703/
# 7    7           http://www.reformagkh.ru/myhouse/profile/view/7716866/
# 8    8           http://www.reformagkh.ru/myhouse/profile/view/9064846/
# 9    9           http://www.reformagkh.ru/myhouse/profile/view/7693685/
# 10   10          http://www.reformagkh.ru/myhouse/profile/view/7806921/
# 11   11          http://www.reformagkh.ru/myhouse/profile/view/7693692/
# ...

# %%
df_uik = pd.read_csv("moscow_uik_buildings.csv")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df_uik.drop(["uik_mapurl","uik_phone"],axis=1,inplace = True)

df_uik[df_uik.street_name == "строителей ул."]#.to_string(index=False)
# Out:
# <ipython-input-25-06be2f8a7718>:6: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#        street_id  uik_number  building_id     street_name  \
# 17150  3610       2266        29389        строителей ул.
# 17151  3610       2274        29390        строителей ул.
# 17152  3610       2266        29391        строителей ул.
# 17153  3610       2266        29392        строителей ул.
# 17154  3610       2266        29393        строителей ул.
# 17155  3610       2267        29394        строителей ул.
# 17156  3610       2267        29395        строителей ул.
# 17157  3610       2267        29396        строителей ул.
# 17158  3610       2266        29398        строителей ул.
# 17159  3610       2266        29399        строителей ул.
# 17160  3610       2274        29400        строителей ул.
# ...

# %%
import geocoder
g = geocoder.osm('улица Вавилова, 86, Москва')
g.osm
# Out:
# {'x': 37.5406266,
#  'y': 55.6765834,
#  'addr:housenumber': '86',
#  'addr:street': 'улица Вавилова',
#  'addr:city': 'Ломоносовский район',
#  'addr:state': 'Москва',
#  'addr:country': 'Россия',
#  'addr:postal': '117393'}
