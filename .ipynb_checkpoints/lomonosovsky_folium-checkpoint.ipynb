# %%
import pandas as pd 
import folium

# %%
df_uik = pd.read_csv("moscow_uik_buildings.csv")

# %%
df_houses = pd.read_excel("lomonosovsky_removed.xlsx")

# %%
df_houses
# Out:
#      Unnamed: 0                                             ссылка  \
# 0             0  http://www.reformagkh.ru/myhouse/profile/view/...
# 1             1  http://www.reformagkh.ru/myhouse/profile/view/...
# 2             2  http://www.reformagkh.ru/myhouse/profile/view/...
# 3             3  http://www.reformagkh.ru/myhouse/profile/view/...
# 4             4  http://www.reformagkh.ru/myhouse/profile/view/...
# ..          ...                                                ...
# 198         198  http://www.reformagkh.ru/myhouse/profile/view/...
# 199         199  http://www.reformagkh.ru/myhouse/profile/view/...
# 200         200  http://www.reformagkh.ru/myhouse/profile/view/...
# 201         201  http://www.reformagkh.ru/myhouse/profile/view/...
# 202         202  http://www.reformagkh.ru/myhouse/profile/view/...
#
#                                               адрес  \
# 0           г. Москва, ул. Академика Пилюгина, д. 4
# 1           г. Москва, ул. Академика Пилюгина, д. 6
# 2     г. Москва, ул. Академика Пилюгина, д. 8, к. 1
# 3     г. Москва, ул. Академика Пилюгина, д. 8, к. 2
# 4    г. Москва, ул. Академика Пилюгина, д. 12, к. 1
# ..                                              ...
# 198          г. Москва, ул. Строителей, д. 13, к. 3
# 199          г. Москва, ул. Строителей, д. 13, к. 4
# 200          г. Москва, ул. Строителей, д. 13, к. 5
# 201          г. Москва, ул. Строителей, д. 17, к. 1
# 202          г. Москва, ул. Строителей, д. 17, к. 2
#
#                                       УК  Год постройки:  \
# 0    ГБУ "Жилищник района Ломоносовский"          2007.0
# 1                       ООО УК «Свитхом»          2008.0
# 2    ГБУ "Жилищник района Ломоносовский"          1982.0
# 3    ГБУ "Жилищник района Ломоносовский"          1999.0
# 4    ГБУ "Жилищник района Ломоносовский"          1982.0
# ..                                   ...             ...
# 198  ГБУ "Жилищник района Ломоносовский"          1957.0
# 199  ГБУ "Жилищник района Ломоносовский"          1957.0
# 200  ГБУ "Жилищник района Ломоносовский"          1957.0
# 201  ГБУ "Жилищник района Ломоносовский"          1956.0
# 202  ГБУ "Жилищник района Ломоносовский"          1959.0
#
#     Серия, тип постройки здания:  Этажность  общая площадь, кв.м  \
# 0          индивидуальный проект       23.0              53700.7
# 1                  инд.панельный       17.0              36863.0
# 2                           КОПЭ       22.0              45265.6
# 3                           П-3м       17.0              17087.6
# 4                           КОПЭ       18.0              41664.3
# ..                           ...        ...                  ...
# 198        индивидуальный проект        5.0               5428.0
# 199        индивидуальный проект        5.0               3291.7
# 200        индивидуальный проект        5.0               5433.6
# 201        индивидуальный проект        7.0               9063.3
# 202        индивидуальный проект        8.0               8709.3
#
#     общая площадь жилых помещений, кв.м общая площадь нежилых помещений, кв.м  \
# 0                             30 238,00                              4 227,00
# 1                             17 554,00                             17 037,00
# 2                             35 113,00                                569,00
# 3                             12 985,00                                291,00
# 4                             31 487,00                                676,00
# ..                                  ...                                   ...
# 198                            3 991,00                                863,00
# 199                            2 672,00                                  9,00
# 200                            4 012,00                                  8,00
# 201                            5 634,00                              1 749,00
# 202                            6 154,00                                782,00
#
#     общая площадь помещений, входящих в состав общего имущества, кв.м  \
# 0                                            19 235,70
# 1                                             2 272,00
# 2                                             9 583,60
# 3                                             3 811,60
# 4                                             9 501,30
# ..                                                 ...
# 198                                             574,00
# 199                                             610,70
# 200                                           1 413,60
# 201                                           1 680,30
# 202                                           1 773,30
#
#     площадь земельного участка, входящего в состав общего имущества в многоквартирном доме, кв.м
# 0                                                 0,00
# 1                                                 0,00
# 2                                                 0,00
# 3                                                 0,00
# 4                                                 0,00
# ..                                                 ...
# 198                                               0,00
# 199                                               0,00
# 200                                               0,00
# 201                                               0,00
# 202                                               0,00
#
# [203 rows x 12 columns]

# %%
import geocoder
g = geocoder.osm('улица Вавилова, 86, Москва')
g.osm
# Out:
# {'x': 37.5406266,
#  'y': 55.6765834,
#  'addr:housenumber': '86',
#  'addr:street': 'улица Вавилова',
#  'addr:city': 'Ломоносовский район',
#  'addr:state': 'Москва',
#  'addr:country': 'Россия',
#  'addr:postal': '117393'}
